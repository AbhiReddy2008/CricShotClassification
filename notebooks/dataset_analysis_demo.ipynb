# %%
import os
import cv2
import pandas as pd

# %%
data = []
rawData_path = "F:/CricShotClassification/Dataset/rawData"

# %%
for class_name in os.listdir(rawData_path):
    class_path = os.path.join(rawData_path,class_name)
    for video in os.listdir(class_path):
        video_path = os.path.join(class_path,video)
        cap = cv2.VideoCapture(video_path)
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        fps = int(cap.get(cv2.CAP_PROP_FPS))
        frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        relative_path = os.path.join("Dataset","rawData",class_name,video)
        duration = frame_count/fps
        is_readable = cap.isOpened()

        data.append([video,class_name,relative_path,frame_count,fps,duration,frame_width,frame_height,is_readable])
        cap.release()

# %%
print(data)
# Out:
# [['vid100_41.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid100_41.avi', 24, 30, 0.8, 896, 540, True], ['vid100_60.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid100_60.avi', 24, 30, 0.8, 896, 540, True], ['vid100_8.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid100_8.avi', 24, 30, 0.8, 896, 540, True], ['vid101_24.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid101_24.avi', 24, 30, 0.8, 896, 540, True], ['vid101_39.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid101_39.avi', 24, 30, 0.8, 896, 540, True], ['vid102_20.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid102_20.avi', 24, 30, 0.8, 896, 540, True], ['vid102_26.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid102_26.avi', 24, 30, 0.8, 896, 540, True], ['vid103_15.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid103_15.avi', 24, 30, 0.8, 896, 540, True], ['vid103_6.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid103_6.avi', 24, 30, 0.8, 896, 540, True], ['vid104_26.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid104_26.avi', 24, 30, 0.8, 896, 540, True], ['vid105_15.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid105_15.avi', 24, 30, 0.8, 896, 540, True], ['vid106_1.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid106_1.avi', 24, 30, 0.8, 896, 540, True], ['vid106_14.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid106_14.avi', 24, 30, 0.8, 896, 540, True], ['vid106_30.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid106_30.avi', 24, 30, 0.8, 896, 540, True], ['vid108_2.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid108_2.avi', 24, 30, 0.8, 896, 540, True], ['vid108_21.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid108_21.avi', 24, 30, 0.8, 896, 540, True], ['vid109_3.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid109_3.avi', 24, 30, 0.8, 896, 540, True], ['vid109_7.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid109_7.avi', 24, 30, 0.8, 896, 540, True], ['vid110_1.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid110_1.avi', 24, 30, 0.8, 896, 540, True], ['vid110_25.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid110_25.avi', 24, 30, 0.8, 896, 540, True], ['vid111_4.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid111_4.avi', 24, 30, 0.8, 896, 540, True], ['vid112_1.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid112_1.avi', 24, 30, 0.8, 896, 540, True], ['vid113_10.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid113_10.avi', 24, 30, 0.8, 896, 540, True], ['vid113_22.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid113_22.avi', 24, 30, 0.8, 896, 540, True], ['vid113_7.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid113_7.avi', 24, 30, 0.8, 896, 540, True], ['vid114_31.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid114_31.avi', 24, 30, 0.8, 896, 540, True], ['vid115_14.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid115_14.avi', 24, 30, 0.8, 896, 540, True], ['vid115_24.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid115_24.avi', 24, 30, 0.8, 896, 540, True], ['vid115_25.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid115_25.avi', 24, 30, 0.8, 896, 540, True], ['vid115_44.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid115_44.avi', 24, 30, 0.8, 896, 540, True], ['vid116_30.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid116_30.avi', 24, 30, 0.8, 896, 540, True], ['vid116_37.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid116_37.avi', 24, 30, 0.8, 896, 540, True], ['vid118_10.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid118_10.avi', 24, 30, 0.8, 896, 540, True], ['vid118_22.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid118_22.avi', 24, 30, 0.8, 896, 540, True], ['vid118_7.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid118_7.avi', 24, 30, 0.8, 896, 540, True], ['vid119_10.avi', 'Cover Drive', 'Dataset\\rawData\\Cover Drive\\vid119_10.avi', 24, 30, 0.8, 896, 540, True], ['vid119_11.avi', 'Cover  ...

# %%
dataframe = pd.DataFrame(data,columns=["video_name","class_name","video_path","frame_count","fps","duration_sec","width","height","is_readable"])


dataframe.to_csv(r"F:\CricShotClassification\Dataset\datasetAnalysis\cricShot10k_dataset_statistics.csv",index=False)
